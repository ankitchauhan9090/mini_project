# %%
from PIL import Image, ImageFilter,ImageEnhance,ImageDraw,ImageFont

# %%
im2 = Image.open('lk.jpg')
im1 = Image.open('lk1.png')

# %%
im1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=250x250 at 0x21659587310>

# %%
print(f"Im1 size in pixels: {im1.size}")
print(f"Im1 height: {im1.height}")
print(f"Im1 width: {im1.width}")
# Out:
# Im1 size in pixels: (250, 250)
# Im1 height: 250
# Im1 width: 250
